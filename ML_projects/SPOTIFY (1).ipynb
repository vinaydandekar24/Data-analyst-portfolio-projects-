# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
spf = pd.read_csv('spotify_churn_dataset.csv')

# %%
spf.head()
# Out:
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# 3                  1           0
# 4                  1           1

# %%
spf.isnull().sum()
# Out:
# user_id                  0
# gender                   0
# age                      0
# country                  0
# subscription_type        0
# listening_time           0
# songs_played_per_day     0
# skip_rate                0
# device_type              0
# ads_listened_per_week    0
# offline_listening        0
# is_churned               0
# dtype: int64

# %% [markdown]
# #

# %%
spf.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
col = ['gender','country', 'subscription_type','device_type']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
for i in col:
    spf[i]=LE.fit_transform(spf[i])

# %%
spf.drop('user_id',axis=1,inplace=True)

# %%
spf.head()
# Out:
#    gender  age  country  subscription_type  listening_time  \
# 0       0   54        1                  1              26
# 1       2   33        2                  0             141
# 2       1   38        0                  2             199
# 3       0   22        1                  3              36
# 4       2   29        7                  0             250
#
#    songs_played_per_day  skip_rate  device_type  ads_listened_per_week  \
# 0                    23       0.20            0                     31
# 1                    62       0.34            2                      0
# 2                    38       0.04            1                      0
# 3                     2       0.31            1                      0
# 4                    57       0.36            1                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# 3                  1           0
# 4                  1           1

# %%
spf.corr()
# Out:
#                          gender       age   country  subscription_type  \
# gender                 1.000000 -0.009925 -0.004235          -0.013962
# age                   -0.009925  1.000000  0.015196          -0.006185
# country               -0.004235  0.015196  1.000000           0.009820
# subscription_type     -0.013962 -0.006185  0.009820           1.000000
# listening_time         0.004202 -0.012975  0.003588           0.014165
# songs_played_per_day   0.012692 -0.006834 -0.012559           0.012231
# skip_rate              0.004333 -0.019557 -0.016346           0.002066
# device_type            0.007439 -0.016369  0.010894          -0.010634
# ads_listened_per_week  0.003859 -0.011962 -0.002306          -0.238393
# offline_listening      0.004498  0.017061 -0.007316           0.271528
# is_churned            -0.000935  0.003982 -0.003236          -0.009537
#
#                        listening_time  songs_played_per_day  skip_rate  \
# gender                       0.004202              0.012692   0.004333
# age                         -0.012975             -0.006834  -0.019557
# country                      0.003588             -0.012559  -0.016346
# subscription_type            0.014165              0.012231   0.002066
# listening_time               1.000000             -0.010996  -0.013603
# songs_played_per_day        -0.010996              1.000000  -0.000590
# skip_rate                   -0.013603             -0.000590   1.000000
# device_type                 -0.004089             -0.008266   0.010204
# ads_listened_per_week        0.002279             -0.017813  -0.012682
# offline_listening           -0.006421              0.018846  -0.002657
# is_churned                  -0.007624              0.009314   0.016121
#
#                        device_type  ads_listened_per_week  offline_listening  \
# gender                    0.007439               0.003859           0.004498
# age                      -0.016369              -0.011962           0.017061
# country                   0.010894              -0.002306          -0.007316
# subscription_type        -0.010634              -0.238393           0.271528
# listening_time           -0.004089               0.002279          -0.006421
# songs_played_per_day     -0.008266              -0.017813           0.018846
# skip_rate                 0.010204              -0.012682          -0.002657
# device_type               1.000000               0.016073          -0.021408
# ads_listened_per_week     0.016073               1.000000          -0.877970
# offline_listening        -0.021408              -0.877970           1.000000
# is_churned               -0.006210              -0.002279           0.012754
#
#                        is_churned
# gender                  -0.000935
# age                      0.003982
# country                 -0.003236
# subscription_type       -0.009537
# listening_time          -0.007624
# songs_played_per_day     0.009314
# skip_rate                0.016121
# device_type             -0.006210
# ads_listened_per_week   -0.002279
# offline_listening        0.012754
# is_churned               1.000000

# %%
spf['skip_rate'] = (spf['skip_rate']*100)
spf['skip_rate'] = spf['skip_rate'].astype(int)
# ii have added this later to suit the data for classification since continous data is not accepted

# %%
spf.boxplot()
plt.xticks(rotation=45);

# %%
spf.head()
# Out:
#    gender  age  country  subscription_type  listening_time  \
# 0       0   54        1                  1              26
# 1       2   33        2                  0             141
# 2       1   38        0                  2             199
# 3       0   22        1                  3              36
# 4       2   29        7                  0             250
#
#    songs_played_per_day  skip_rate  device_type  ads_listened_per_week  \
# 0                    23         20            0                     31
# 1                    62         34            2                      0
# 2                    38          4            1                      0
# 3                     2         31            1                      0
# 4                    57         36            1                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# 3                  1           0
# 4                  1           1

# %%
spf_class = spf.copy()

# %%
sns.kdeplot(data=spf, x='ads_listened_per_week')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler

# %%
SS = StandardScaler()

# %%
spf.columns
# Out:
# Index(['gender', 'age', 'country', 'subscription_type', 'listening_time',
#        'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
cols = ['gender', 'age', 'country', 'subscription_type', 'listening_time',
       'songs_played_per_day', 'skip_rate', 'device_type',
       'ads_listened_per_week', 'offline_listening', 'is_churned']

# %%
for i in cols:
    spf[i] = SS.fit_transform(spf[[i]])

# %%
spf.boxplot()
plt.xticks(rotation=45);

# %% [markdown]
# #

# %% [markdown]
# # Using classification techniques

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
RF = RandomForestClassifier()

# %%
X = spf_class.drop('is_churned', axis=1)

# %%
y = spf_class['is_churned']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 42)

# %%
y_train.value_counts()
# Out:
# is_churned
# 0    4131
# 1    1469
# Name: count, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# As you can see that there is a lot of bias in data now we have to handel bias

# %% [markdown]
# ##

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_train, y_train)

# %%
y_res.value_counts()
# Out:
# is_churned
# 0    4131
# 1    4131
# Name: count, dtype: int64

# %%
RF.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
y_pred = RF.predict(X_test)

# %% [markdown]
# #

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import f1_score,accuracy_score,confusion_matrix

# %%
f1_score(y_test,y_pred)
# Out:
# 0.28663967611336033

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6329166666666667

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1342,  456],
#        [ 425,  177]])

# %% [markdown]
# #

# %% [markdown]
# # Using Logistic Regression

# %% [markdown]
# Using logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(X_res,y_res)
# Out:
# C:\Users\Daksh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LR_pred=LR.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,LR_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.57      0.65      1798
#            1       0.25      0.43      0.32       602
#
#     accuracy                           0.53      2400
#    macro avg       0.50      0.50      0.48      2400
# weighted avg       0.62      0.53      0.56      2400

# %%
confusion_matrix(y_test,LR_pred)
# Out:
# array([[1021,  777],
#        [ 343,  259]])

# %% [markdown]
# #

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(X_res,y_res)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = DTC.predict(X_test)

# %% [markdown]
# #

# %% [markdown]
# # Evaluation

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.61      0.67      1798
#            1       0.24      0.38      0.30       602
#
#     accuracy                           0.55      2400
#    macro avg       0.49      0.49      0.48      2400
# weighted avg       0.62      0.55      0.58      2400

# %%
f1_score(y_test,y_pred)
# Out:
# 0.2961992136304063
